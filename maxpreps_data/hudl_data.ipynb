# %%
import requests
import pandas as pd
import numpy as np

# %%
#Dataframe
data = {
    "Date": [
        "Nov 15, 2023", "Nov 16, 2023", "Nov 17, 2023", "Nov 18, 2023", "Nov 28, 2023", "Nov 30, 2023",
        "Dec 2, 2023", "Dec 5, 2023", "Dec 8, 2023", "Dec 11, 2023", "Dec 14, 2023", "Dec 15, 2023", 
        "Dec 16, 2023", "Dec 22, 2023", "Dec 27, 2023", "Dec 28, 2023", "Dec 29, 2023", "Dec 30, 2023"
    ],
    "Opponent": [
        "Kingman High School", "Verdugo Hills", "Trabuco Hills", "Portola", "Magnolia Science Academy", 
        "Legacy College Prep", "Hueneme High School", "Sherman Indian", "Eastside Christian", 
        "Verbum Dei", "Anaheim High", "Huntington Beach", "Yorba Linda", "Avalon", "Desert Hot Springs", "Palo Verde Valley", 
        "Xavier Prep High", "Royal High School"
    ],
    "Home/Away": [
        "Home", "Home", "Home", "Home", "Away", "Home", "Home", "Away", "Home", "Away", "Neutral", 
        "Neutral", "Neutral", "Away", "Neutral", "Neutral", "Neutral", "Neutral"
    ],
    "Points OVHS": [73, 42, 19, 53, 84, 65, 65, 66, 86, 47, 69, 32, 30, 72, 55, 49, 54, 45],
    "Points Opponent": [38, 65, 71, 75, 25, 19, 29, 33, 10, 68, 52, 55, 69, 31, 27, 44, 41, 62],
    "Rebounds OVHS": [31, 31, 24, 31, 46, 30, 42, 42, 44, 30, 43, 32, 26, 45, 42, 32, 26, 29],
    "Rebounds Opponent": [39, 31, 36, 37, 38, 25, 30, 36, 19, 35, 26, 32, 48, 25, 30, 38, 31, 32],
    "Assists OVHS": [15, 5, 4, 14, 17, 15, 11, 21, 15, 9, 18, 3, 6, 16, 12, 15, 19, 14],
    "Assists Opponent": [9, 14, 20, 18, 0, 3, 7, 7, 1, 9, 15, 8, 13, 8, 4, 11, 7, 11],
    "Steals OVHS": [15, 3, 3, 7, 24, 23, 12, 21, 22, 6, 11, 3, 1, 11, 10, 8, 9, 8],
    "Steals Opponent": [7, 16, 11, 15, 7, 3, 5, 12, 3, 17, 6, 15, 10, 6, 7, 8, 7, 7],
    "Blocks OVHS": [0, 1, 0, 1, 0, 1, 2, 0, 0, 0, 1, 2, 1, 1, 2, 1, 2, 2],
    "Blocks Opponent": [2, 4, 2, 3, 2, 1, 0, 5, 0, 2, 2, 1, 3, 3, 3, 7, 0, 1],
    "FG% OVHS": [44, 39, 9, 36, 46, 47, 43, 40, 54, 33, 43, 31, 23, 42, 34, 35, 43, 36],
    "FG% Opponent": [35, 44, 58, 46, 20, 26, 22, 24, 11, 47, 40, 38, 42, 29, 26, 37, 36, 45],
    "3PT% OVHS": [39, 19, 0, 31, 24, 23, 25, 24, 32, 22, 31, 0, 15, 21, 30, 23, 35, 29],
    "3PT% Opponent": [11, 32, 25, 23, 22, 0, 20, 15, 5, 35, 41, 6, 19, 22, 6, 33, 32, 30],
    "FT% OVHS": [62, 27, 69, 40, 43, 30, 88, 67, 67, 69, 52, 62, 46, 45, 67, 55, 56, 83],
    "FT% Opponent": [50, 100, 67, 73, 75, 50, 50, 71, 33, 60, 43, 100, 80, 75, 20, 50, 45, 75]
}

# Creating the combined DataFrame
df = pd.DataFrame(data)

df
# Out:
#             Date                  Opponent Home/Away  Points OVHS  \
# 0   Nov 15, 2023       Kingman High School      Home           73
# 1   Nov 16, 2023             Verdugo Hills      Home           42
# 2   Nov 17, 2023             Trabuco Hills      Home           19
# 3   Nov 18, 2023                   Portola      Home           53
# 4   Nov 28, 2023  Magnolia Science Academy      Away           84
# 5   Nov 30, 2023       Legacy College Prep      Home           65
# 6    Dec 2, 2023       Hueneme High School      Home           65
# 7    Dec 5, 2023            Sherman Indian      Away           66
# 8    Dec 8, 2023        Eastside Christian      Home           86
# 9   Dec 11, 2023                Verbum Dei      Away           47
# 10  Dec 14, 2023              Anaheim High   Neutral           69
# 11  Dec 15, 2023          Huntington Beach   Neutral           32
# 12  Dec 16, 2023               Yorba Linda   Neutral           30
# ...
